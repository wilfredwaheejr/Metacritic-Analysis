# %%
#Loading and Reading CSV Files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Add dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
#Files to load
games_data_to_load = "../Data/games_scores.csv"
movies_data_to_load = "../Data/movies_scores.csv"
music_data_to_load = "../Data/music_scores.csv"
tv_data_to_load = "../Data/tv_scores.csv"

# %%
#Read data
games_data_df = pd.read_csv(games_data_to_load)
movies_data_df = pd.read_csv(movies_data_to_load)
music_data_df = pd.read_csv(music_data_to_load)
tv_data_df = pd.read_csv(tv_data_to_load)

# %%
# Display the data table for preview
music_data_df.head()
# Out:
#       id            artist  metascore        release_date  sort_no  \
# 0  13354  Wadada Leo Smith         99        May 22, 2012        1
# 1  37516       Fiona Apple         98      April 17, 2020        2
# 2   1671      Brian Wilson         97  September 28, 2004        3
# 3   1538      Loretta Lynn         97      April 27, 2004        4
# 4  22163    Kendrick Lamar         96      March 16, 2015        5
#
#                                              summary                   title  \
# 0  The four-disc set from the jazz trumpeter was ...     Ten Freedom Summers
# 1  The fifth full-length studio release for the a...  Fetch the Bolt Cutters
# 2  Well, better 37 years late than never. Origina...                   SMiLE
# 3  It's been over 40 years since she released her...           Van Lear Rose
# 4  The third full-length studio release from the ...     To Pimp A Butterfly
#
#   user_score
# 0        4.2
# 1        8.1
# 2        7.9
# 3        8.4
# 4        8.9

# %%
#Drop "tbd" user_score rows before calculating the weighted average
games = games_data_df[games_data_df.user_score!="tbd"]
movies = movies_data_df[movies_data_df.user_score!="tbd"]
music = music_data_df[music_data_df.user_score!="tbd"]
tv = tv_data_df[tv_data_df.user_score!="tbd"]

# %%
games.drop(columns=["id"], inplace=True)
movies.drop(columns=["id"], inplace=True)
music.drop(columns=["id"], inplace=True)
tv.drop(columns=["id"], inplace=True)
# Out:
# /Users/wilfredwaheejr./opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#rename "sort_no" column so that we can reference the original rank after
games = games.rename(columns={'sort_no': 'original_metarank'})
movies = movies.rename(columns={'sort_no': 'original_metarank'})
music = music.rename(columns={'sort_no': 'original_metarank'})
tv = tv.rename(columns={'sort_no': 'original_metarank'})

# %%
music.head()
# Out:
#              artist  metascore        release_date  original_metarank  \
# 0  Wadada Leo Smith         99        May 22, 2012                  1
# 1       Fiona Apple         98      April 17, 2020                  2
# 2      Brian Wilson         97  September 28, 2004                  3
# 3      Loretta Lynn         97      April 27, 2004                  4
# 4    Kendrick Lamar         96      March 16, 2015                  5
#
#                                              summary                   title  \
# 0  The four-disc set from the jazz trumpeter was ...     Ten Freedom Summers
# 1  The fifth full-length studio release for the a...  Fetch the Bolt Cutters
# 2  Well, better 37 years late than never. Origina...                   SMiLE
# 3  It's been over 40 years since she released her...           Van Lear Rose
# 4  The third full-length studio release from the ...     To Pimp A Butterfly
#
#   user_score
# 0        4.2
# 1        8.1
# 2        7.9
# 3        8.4
# 4        8.9

# %%
#Check column data types
music.dtypes
# Out:
# artist               object
# metascore             int64
# release_date         object
# original_metarank     int64
# summary              object
# title                object
# user_score           object
# dtype: object

# %%
#Convert the user score column to a numberic
games["user_score"] = pd.to_numeric(games["user_score"])
movies["user_score"] = pd.to_numeric(movies["user_score"])
music["user_score"] = pd.to_numeric(music["user_score"])
tv["user_score"] = pd.to_numeric(tv["user_score"])

# %%
#Multiply the user score column by 10 to match the metascore
games.user_score = games.user_score.multiply(10)
movies.user_score = movies.user_score.multiply(10)
music.user_score = music.user_score.multiply(10)
tv.user_score = tv.user_score.multiply(10)

# %%
#Covert the metascore column to a float to match the user score
games["metascore"] = games["metascore"].astype(np.float64)
movies["metascore"] = movies["metascore"].astype(np.float64)
music["metascore"] = music["metascore"].astype(np.float64)
tv["metascore"] = tv["metascore"].astype(np.float64)

# %%
music.dtypes
# Out:
# artist                object
# metascore            float64
# release_date          object
# original_metarank      int64
# summary               object
# title                 object
# user_score           float64
# dtype: object

# %%
music.head()
# Out:
#              artist  metascore        release_date  original_metarank  \
# 0  Wadada Leo Smith       99.0        May 22, 2012                  1
# 1       Fiona Apple       98.0      April 17, 2020                  2
# 2      Brian Wilson       97.0  September 28, 2004                  3
# 3      Loretta Lynn       97.0      April 27, 2004                  4
# 4    Kendrick Lamar       96.0      March 16, 2015                  5
#
#                                              summary                   title  \
# 0  The four-disc set from the jazz trumpeter was ...     Ten Freedom Summers
# 1  The fifth full-length studio release for the a...  Fetch the Bolt Cutters
# 2  Well, better 37 years late than never. Origina...                   SMiLE
# 3  It's been over 40 years since she released her...           Van Lear Rose
# 4  The third full-length studio release from the ...     To Pimp A Butterfly
#
#    user_score
# 0        42.0
# 1        81.0
# 2        79.0
# 3        84.0
# 4        89.0

# %%
#Calculate the weighted average of metascores and user scores combined
games_weight_average = games["user_score"]*.6 + games["metascore"]*.4
movies_weight_average = movies["user_score"]*.6 + movies["metascore"]*.4
music_weight_average = music["user_score"]*.6 + music["metascore"]*.4
tv_weight_average = tv["user_score"]*.6 + tv["metascore"]*.4

# %%
#Add weighted average column to data frames
games = games.assign(weighted_average = games_weight_average)
movies = movies.assign(weighted_average = movies_weight_average)
music = music.assign(weighted_average = music_weight_average)
tv = tv.assign(weighted_average = tv_weight_average)

# %%
music.head()
# Out:
#              artist  metascore        release_date  original_metarank  \
# 0  Wadada Leo Smith       99.0        May 22, 2012                  1
# 1       Fiona Apple       98.0      April 17, 2020                  2
# 2      Brian Wilson       97.0  September 28, 2004                  3
# 3      Loretta Lynn       97.0      April 27, 2004                  4
# 4    Kendrick Lamar       96.0      March 16, 2015                  5
#
#                                              summary                   title  \
# 0  The four-disc set from the jazz trumpeter was ...     Ten Freedom Summers
# 1  The fifth full-length studio release for the a...  Fetch the Bolt Cutters
# 2  Well, better 37 years late than never. Origina...                   SMiLE
# 3  It's been over 40 years since she released her...           Van Lear Rose
# 4  The third full-length studio release from the ...     To Pimp A Butterfly
#
#    user_score  weighted_average
# 0        42.0              64.8
# 1        81.0              87.8
# 2        79.0              86.2
# 3        84.0              89.2
# 4        89.0              91.8

# %%
music.dtypes
# Out:
# artist                object
# metascore            float64
# release_date          object
# original_metarank      int64
# summary               object
# title                 object
# user_score           float64
# weighted_average     float64
# dtype: object

# %%
#Sort records by the weighted average of scores
music.sort_values(by='weighted_average', ascending=False)
# Out:
#                    artist  metascore       release_date  original_metarank  \
# 4          Kendrick Lamar       96.0     March 16, 2015                  5
# 729                  RAYE       88.0   February 3, 2023                141
# 8                 Outkast       95.0   October 31, 2000                  9
# 16             Madvillain       93.0     March 23, 2004                 17
# 38            Weyes Blood       91.0      April 5, 2019                 39
# ...                   ...        ...                ...                ...
# 13144        Viva Brother       34.0     August 1, 2011              13318
# 13142         Dirty Vegas       35.0  November 30, 2004              13316
# 13136             6ix9ine       38.0  November 27, 2018              13310
# 13119  Soulja Boy Tell Em       42.0  December 16, 2008              13292
# 13146     Kevin Federline       15.0   October 31, 2006              13320
#
#                                                  summary  \
# 4      The third full-length studio release from the ...
# 729    The debut full-length release for London-based...
# 8      Featuring the hit singles "B.O.B." and "Ms. Ja...
# 16     'Madvillainy' is a collaboration between rappe...
# 38     The fourth full-length release for Natalie Mer...
# ...                                                  ...
# 13144  The debut album for the British pop rock band,...
# 13142  The UK dance trio returns with a sophomore rel...
# 13136  The debut full-length studio release for the r...
# 13119  The follow-up to Souljboytellem.com was produc...
# 13146  Now that Britney has dumped him, all he has is...
#
#                        title  user_score  weighted_average
# 4        To Pimp A Butterfly        89.0              91.8
# 729    My 21st Century Blues        93.0              91.0
# 8                  Stankonia        88.0              90.8
# 16               Madvillainy        89.0              90.6
# 38            Titanic Rising        90.0              90.4
# ...                      ...         ...               ...
# 13144     Famous First Words        25.0              28.6
# 13142                    One        24.0              28.4
# 13136              DUMMY BOY        18.0              26.0
# 13119       iSouljaBoyTellem        14.0              25.2
# 13146      Playing With Fire        22.0              19.2
#
# [9412 rows x 8 columns]

# %%
games['adjusted_metarank'] = games['weighted_average'].rank(ascending=False)
movies['adjusted_metarank'] = movies['weighted_average'].rank(ascending=False)
music['adjusted_metarank'] = music['weighted_average'].rank(ascending=False)
tv['adjusted_metarank'] = tv['weighted_average'].rank(ascending=False)

# %%
#Sort files by their adjusted metarank
music.sort_values(by='adjusted_metarank', ascending=True)
# Out:
#                    artist  metascore       release_date  original_metarank  \
# 4          Kendrick Lamar       96.0     March 16, 2015                  5
# 729                  RAYE       88.0   February 3, 2023                141
# 8                 Outkast       95.0   October 31, 2000                  9
# 16             Madvillain       93.0     March 23, 2004                 17
# 38            Weyes Blood       91.0      April 5, 2019                 39
# ...                   ...        ...                ...                ...
# 13144        Viva Brother       34.0     August 1, 2011              13318
# 13142         Dirty Vegas       35.0  November 30, 2004              13316
# 13136             6ix9ine       38.0  November 27, 2018              13310
# 13119  Soulja Boy Tell Em       42.0  December 16, 2008              13292
# 13146     Kevin Federline       15.0   October 31, 2006              13320
#
#                                                  summary  \
# 4      The third full-length studio release from the ...
# 729    The debut full-length release for London-based...
# 8      Featuring the hit singles "B.O.B." and "Ms. Ja...
# 16     'Madvillainy' is a collaboration between rappe...
# 38     The fourth full-length release for Natalie Mer...
# ...                                                  ...
# 13144  The debut album for the British pop rock band,...
# 13142  The UK dance trio returns with a sophomore rel...
# 13136  The debut full-length studio release for the r...
# 13119  The follow-up to Souljboytellem.com was produc...
# 13146  Now that Britney has dumped him, all he has is...
#
#                        title  user_score  weighted_average  adjusted_metarank
# 4        To Pimp A Butterfly        89.0              91.8                1.0
# 729    My 21st Century Blues        93.0              91.0                2.0
# 8                  Stankonia        88.0              90.8                3.0
# 16               Madvillainy        89.0              90.6                4.0
# 38            Titanic Rising        90.0              90.4                5.5
# ...                      ...         ...               ...                ...
# 13144     Famous First Words        25.0              28.6             9407.5
# 13142                    One        24.0              28.4             9409.0
# 13136              DUMMY BOY        18.0              26.0             9410.0
# 13119       iSouljaBoyTellem        14.0              25.2             9411.0
# 13146      Playing With Fire        22.0              19.2             9412.0
#
# [9412 rows x 9 columns]

# %%
movies.sort_values(by='adjusted_metarank', ascending=True)
# Out:
#        metascore     rating        release_date  original_metarank  \
# 101        100.0          R      March 24, 1972                  2
# 104        100.0      TV-PG    January 23, 1943                  5
# 103        100.0       TV-G   September 1, 1954                  4
# 145         96.0         PG  September 20, 2002                 46
# 111         99.0     Passed       March 7, 1931                 12
# ...          ...        ...                 ...                ...
# 15276       11.0      PG-13      April 22, 2005              15277
# 15319        1.0        NaN   November 14, 2003              15320
# 15304        8.0  Not Rated       July 18, 2014              15305
# 15320        1.0         PG     August 22, 1987              15321
# 15321        1.0  Not Rated        June 5, 2015              15322
#
#                                                  summary  \
# 101    Francis Ford Coppola's epic features Marlon Br...
# 104    A Casablanca, Morocco casino owner in 1941 she...
# 103    A wheelchair-bound photographer spies on his n...
# 145    A young girl, Chihiro, becomes trapped in a st...
# 111    The Tramp (Charlie Chaplin) struggles to help ...
# ...                                                  ...
# 15276  When a wealthy businessman is faced with a div...
# 15319  Two lovers, killed during the Holocaust, are r...
# 15304  An annual 4th of July weekend hosted by troubl...
# 15320  Dodger must confront the struggles of life as ...
# 15321  Three men—Jules Rimet (Gérard Depardieu), Joao...
#
#                              title  user_score  weighted_average  \
# 101                  The Godfather        92.0              95.2
# 104                     Casablanca        88.0              92.8
# 103                    Rear Window        87.0              92.2
# 145                  Spirited Away        89.0              91.8
# 111                    City Lights        87.0              91.8
# ...                            ...         ...               ...
# 15276                King's Ransom        14.0              12.8
# 15319           The Singing Forest        20.0              12.4
# 15304                 Among Ravens         9.0               8.6
# 15320  The Garbage Pail Kids Movie         7.0               4.6
# 15321              United Passions         7.0               4.6
#
#        adjusted_metarank
# 101                  1.0
# 104                  2.0
# 103                  3.0
# 145                  4.0
# 111                  5.0
# ...                  ...
# 15276            12112.0
# 15319            12113.0
# 15304            12114.0
# 15320            12115.5
# 15321            12115.5
#
# [12116 rows x 9 columns]

# %%
games.sort_values(by='adjusted_metarank', ascending=True)
# Out:
#        metascore       platform       release_date  original_metarank  \
# 100         99.0    Nintendo 64  November 23, 1998                  1
# 142         96.0  PlayStation 2   October 25, 2005                 43
# 64          91.0    PlayStation  November 11, 1999                365
# 21          91.0       GameCube     April 30, 2002                322
# 608         94.0      Dreamcast  February 29, 2000                109
# ...          ...            ...                ...                ...
# 20007       22.0       Xbox 360       May 21, 2013              20008
# 20016       17.0       Xbox 360      April 5, 2013              20017
# 20013       19.0             PC      June 11, 2015              20014
# 20014       19.0       Xbox 360      June 25, 2013              20015
# 20020       16.0             PC      June 24, 2013              20021
#
#                                                  summary  \
# 100    As a young boy, Link is tricked by Ganondorf, ...
# 142    In Resident Evil 4 players are reacquainted wi...
# 64     A month and a half have passed since the mansi...
# 21     Raccoon City has been completely overrun by mu...
# 608    Resident Evil Code: Veronica takes up the stor...
# ...                                                  ...
# 20007  Fast & Furious: Showdown takes some of the fra...
# 20016  A remake the 80's Double Dragon II game. Team ...
# 20013  A dire curse has shrouded the town of Lorwich ...
# 20014  The game is set in the last years of the roari...
# 20020  The game is set in the last years of the roari...
#
#                                          title  user_score  weighted_average  \
# 100       The Legend of Zelda: Ocarina of Time        91.0              94.2
# 142                            Resident Evil 4        93.0              94.2
# 64                    Resident Evil 3: Nemesis        96.0              94.0
# 21                        Resident Evil (2002)        96.0              94.0
# 608               Resident Evil Code: Veronica        94.0              94.0
# ...                                        ...         ...               ...
# 20007                 Fast & Furious: Showdown        13.0              16.6
# 20016  Double Dragon II: Wander of the Dragons        16.0              16.4
# 20013          Alone in the Dark: Illumination        13.0              15.4
# 20014                Ride to Hell: Retribution        13.0              15.4
# 20020                Ride to Hell: Retribution        14.0              14.8
#
#        adjusted_metarank
# 100                  1.5
# 142                  1.5
# 64                   4.0
# 21                   4.0
# 608                  4.0
# ...                  ...
# 20007            18636.0
# 20016            18637.0
# 20013            18638.5
# 20014            18638.5
# 20020            18640.0
#
# [18640 rows x 9 columns]

# %%
tv.sort_values(by='adjusted_metarank', ascending=True)
# Out:
#       metascore        release_date  original_metarank  \
# 4          99.0       July 15, 2012                  5
# 33         95.0       July 11, 2022                 34
# 21         96.0       July 17, 2011                 22
# 37         94.0      April 18, 2022                 38
# 9          98.0  September 19, 2004                 10
# ...         ...                 ...                ...
# 3134       39.0  September 25, 2017               3135
# 3240       30.0  September 14, 2011               3241
# 3108       40.0    January 24, 2020               3109
# 3190       35.0  September 18, 2018               3191
# 3293       19.0     January 3, 2012               3294
#
#                                                 summary  \
# 4     The final season for the award-winning drama b...
# 33    The second half of the sixth and final season ...
# 21    Walter (Bryan Cranston) has more trouble on hi...
# 37    The sixth and final season of the Breaking Bad...
# 9     In chronicling a multi-generational family bus...
# ...                                                 ...
# 3134  The morning talk show hosted by former Fox New...
# 3240  Mario Lopez hosts this reality show where cele...
# 3108  The documentary series hosted by Gwyneth Paltr...
# 3190  Former Celebrity Apprentice contestant Tom Arn...
# 3293  After they are laid off, Lee Standish (Ben Kol...
#
#                                                   title  user_score  \
# 4                                Breaking Bad: Season 5        97.0
# 33                         Better Call Saul: Season 6.5        97.0
# 21                               Breaking Bad: Season 4        95.0
# 37                           Better Call Saul: Season 6        94.0
# 9                                    The Wire: Season 3        91.0
# ...                                                 ...         ...
# 3134                        Megyn Kelly Today: Season 1         9.0
# 3240                                      H8R: Season 1        15.0
# 3108        The Goop Lab with Gwyneth Paltrow: Season 1         8.0
# 3190  The Hunt for the Trump Tapes with Tom Arnold: ...         9.0
# 3293                                 Work It : Season 1         9.0
#
#       weighted_average  adjusted_metarank
# 4                 97.8                1.0
# 33                96.2                2.0
# 21                95.4                3.0
# 37                94.0                4.0
# 9                 93.8                5.5
# ...                ...                ...
# 3134              21.0             2993.5
# 3240              21.0             2993.5
# 3108              20.8             2995.0
# 3190              19.4             2996.0
# 3293              13.0             2997.0
#
# [2997 rows x 8 columns]

# %%
#Files to save

from pathlib import Path  
filepath1 = Path("../Data/adjusted_games_scores.csv") 
filepath1.parent.mkdir(parents=True, exist_ok=True)  
games.to_csv(filepath1)

# %%
filepath2 = Path("../Data/adjusted_movies_scores.csv") 
filepath2.parent.mkdir(parents=True, exist_ok=True)  
movies.to_csv(filepath2)

# %%
filepath3 = Path("../Data/adjusted_music_scores.csv") 
filepath3.parent.mkdir(parents=True, exist_ok=True)  
music.to_csv(filepath3)

# %%
filepath4 = Path("../Data/adjusted_tv_scores.csv") 
filepath4.parent.mkdir(parents=True, exist_ok=True)  
tv.to_csv(filepath4)
